# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
customer = pd.read_csv("Customer.csv")
prod_info = pd.read_csv("prod_cat_info.csv")
transaction = pd.read_csv("Transactions.csv")

# %%
customer.shape
# Out:
# (5647, 4)

# %%
prod_info.shape
# Out:
# (23, 4)

# %%
transaction.shape
# Out:
# (23053, 10)

# %%
customer.head(5)
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
prod_info.head(5)
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %%
transaction.head(5)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
prod_info.rename(columns={"prod_sub_cat_code":"prod_subcat_code"},inplace=True)

# %%
pd.merge?

# %%
merge1 = pd.merge(left=transaction, right=prod_info,on=["prod_cat_code","prod_subcat_code"],how="left")

# %%
prod_info
# Out:
#     prod_cat_code          prod_cat  prod_subcat_code          prod_subcat
# 0               1          Clothing                 4                 Mens
# 1               1          Clothing                 1                Women
# 2               1          Clothing                 3                 Kids
# 3               2          Footwear                 1                 Mens
# 4               2          Footwear                 3                Women
# 5               2          Footwear                 4                 Kids
# 6               3       Electronics                 4              Mobiles
# 7               3       Electronics                 5            Computers
# 8               3       Electronics                 8  Personal Appliances
# 9               3       Electronics                 9              Cameras
# 10              3       Electronics                10      Audio and video
# ...

# %%
merge1
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
#1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to
#keep all customers who have done transactions with us and select the join type accordingly

# %%
customer_final = pd.merge(left=merge1, right=customer,right_on="customer_Id", left_on="cust_id", how="left")

# %%
customer_final.head(5)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id         DOB Gender  city_code
# ...

# %%
#2. Prepare a summary report for the merged data set.

# %%
customer_final.shape
# Out:
# (23053, 16)

# %%
transaction.shape
# Out:
# (23053, 10)

# %%
customer_final.dtypes
# Out:
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# prod_cat             object
# prod_subcat          object
# customer_Id           int64
# DOB                  object
# Gender               object
# city_code           float64
# dtype: object

# %%
#convert DOB and tran_date in date time format

# %%
customer_final["DOB"] = pd.to_datetime(customer_final["DOB"], format="%d-%m-%Y")

# %%
customer_final.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date                   object
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# dtype: object

# %%
customer_final["tran_date"] = pd.to_datetime(customer_final["tran_date"])

# %%
customer_final.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# dtype: object

# %%
# check for duplicate values
customer_final.duplicated().sum()
# Out:
# 13

# %%
customer_final.drop_duplicates(inplace=True)

# %%
customer_final.duplicated().sum()
# Out:
# 0

# %%
customer_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
#2. Get the column names and their corresponding data types
customer_final.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_subcat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt', 'Store_type',
#        'prod_cat', 'prod_subcat', 'customer_Id', 'DOB', 'Gender', 'city_code'],
#       dtype='object')

# %%
customer_final.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# dtype: object

# %%
#2(B). Top/Bottom 10 observations
customer_final.head(10)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
# 5     97439039119   272357 2014-02-23                 8              3   -2
# 6     45649838090   273667 2014-02-22                11              6   -1
# 7     22643667930   271489 2014-02-22                12              6   -1
# 8     79792372943   275108 2014-02-22                 3              1   -3
# 9     50076728598   269014 2014-02-21                 8              3   -4
#
#    Rate      Tax  total_amt Store_type          prod_cat          prod_subcat  \
# ...

# %%
customer_final.tail(10)
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 23043     49882891062   271982 2011-01-25                10              5
# 23044     14787475597   273982 2011-01-25                 4              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23046     40893803228   272049 2011-01-25                11              6
# 23047     30856003613   266866 2011-01-25                 4              2
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
#        Qty  Rate      Tax  total_amt Store_type          prod_cat  \
# 23043    4  1330  558.600   5878.600     e-Shop             Books
# ...

# %%
#2(C). “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)
customer_final.describe()
# Out:
#        transaction_id        cust_id  prod_subcat_code  prod_cat_code  \
# count    2.304000e+04   23040.000000      23040.000000   23040.000000
# mean     5.006955e+10  271021.880252          6.148785       3.763498
# std      2.898062e+10    2431.573668          3.726197       1.677091
# min      3.268991e+06  266783.000000          1.000000       1.000000
# 25%      2.493315e+10  268935.000000          3.000000       2.000000
# 50%      5.009188e+10  270980.500000          5.000000       4.000000
# 75%      7.532632e+10  273114.250000         10.000000       5.000000
# max      9.998755e+10  275265.000000         12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt    customer_Id  \
# count  23040.000000  23040.000000  23040.000000  23040.000000   23040.000000
# mean       2.435764    637.094965    248.677488   2109.865226  271021.880252
# std        2.264326    621.727374    187.188311   2505.610295    2431.573668
# ...

# %%
#2(D). Frequency tables for all the categorical variables

# %%
categorical=customer_final.loc[:,customer_final.dtypes=="object"]
categorical
# Out:
#       Store_type          prod_cat prod_subcat Gender
# 0         e-Shop          Clothing       Women      M
# 1         e-Shop       Electronics   Computers      F
# 2       TeleShop             Books         DIY      M
# 3         e-Shop  Home and kitchen        Bath      M
# 4       TeleShop             Books         DIY      M
# ...          ...               ...         ...    ...
# 23048     e-Shop             Books    Academic      M
# 23049     e-Shop          Clothing        Mens      M
# 23050        MBR  Home and kitchen  Furnishing      M
# 23051   TeleShop             Books    Children      M
# 23052   TeleShop             Books    Children      M
#
# [23040 rows x 4 columns]

# %%
#3. Generate histograms for all continuous variables and frequency bars for categorical variables

# %%
#Calculate the following information using the merged dataset:
#Time period of the available transaction data

# %%
cat_customer = customer_final.loc[:,customer_final.dtypes=='object']

# %%
sns.countplot(cat_customer['Gender'])
plt.show()
# Out:
# C:\Users\TSL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(category_customer['Store_type'])
plt.show()
# Out:
# C:\Users\TSL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(category_customer['prod_cat'])
plt.show()
# Out:
# C:\Users\TSL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#. 4(A) Time period of the available transaction data

# %%
customer_final.sort_values(by="tran_date")
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 22899     36332303449   268624 2011-01-02                10              6
# 22893     25374972356   268904 2011-01-02                 2              6
# 22894     15662366857   272756 2011-01-02                 5              3
# 22895     28972634039   275227 2011-01-02                 9              3
# 22896     60041644943   267309 2011-01-02                 3              2
# ...               ...      ...        ...               ...            ...
# 161       65228973233   270009 2014-12-02                11              5
# 162       83661978186   274678 2014-12-02                10              3
# 147       36792372906   275246 2014-12-02                 2              6
# 154       74023090711   271180 2014-12-02                 8              3
# 146       17146707816   274897 2014-12-02                12              5
#
# ...

# %%
first_date = customer_final["tran_date"].min()
first_date
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
last_date = customer_final["tran_date"].max()
last_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
print(["first_date"]+"to"+ ["last_date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-258-77e788a5cd4b> in <module>
# ----> 1 print(["first_date"]+"to"+ ["last_date"])
#
# TypeError: can only concatenate list (not "str") to list

# %%
#4(B) Count of transactions where the total amount of transaction was negative

# %%
negative_transaction = customer_final.loc[customer_final["total_amt"] < 0,"transaction_id"].count()
negative_transaction

# %%
#5. Analyze which product categories are more popular among females vs male customers

# %%
product_cat = customer_final.groupby(["Gender","prod_cat"])[["Qty"]].sum()
product_cat
# Out:
#                           Qty
# Gender prod_cat
# F      Bags              2364
#        Books             7080
#        Clothing          3425
#        Electronics       5832
#        Footwear          3721
#        Home and kitchen  4898
# M      Bags              2346
#        Books             7587
#        Clothing          3748
#        Electronics       6486
#        Footwear          3561
#        Home and kitchen  5051

# %%
#6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
customer_max = customer_final.groupby('city_code')['customer_Id'].count().sort_values(ascending =False)
customer_max
# Out:
# city_code
# 4.0     2422
# 3.0     2410
# 5.0     2357
# 7.0     2356
# 10.0    2333
# 8.0     2328
# 2.0     2268
# 1.0     2255
# 9.0     2176
# 6.0     2127
# Name: customer_Id, dtype: int64

# %%
customer_max1=customer_max.sum()
customer_max1
# Out:
# 23032

# %%
pct=customer_max/customer_max1*100
pct
# Out:
# city_code
# 4.0     10.515804
# 3.0     10.463703
# 5.0     10.233588
# 7.0     10.229246
# 10.0    10.129385
# 8.0     10.107676
# 2.0      9.847169
# 1.0      9.790726
# 9.0      9.447725
# 6.0      9.234977
# Name: customer_Id, dtype: float64

# %%
#7. Which store type sells the maximum products by value and by quantity?
customer_final.head(5)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id        DOB Gender  city_code
# 0       270351 1981-09-26      M        5.0
# ...

# %%
customer_final.groupby("Store_type")["Qty","Rate"].sum()
customer_final
# Out:
# <ipython-input-265-73dbeeed3a38>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   customer_final.groupby("Store_type")["Qty","Rate"].sum()
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# ...

# %%
#8.  What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
#pending

# %%
9. #What was the total amount earned from "Male" customers under the "Electronics" category?
# Out:
# 9.0

# %%
male_electronics_earning=customer_final.groupby(["Gender","prod_cat"])[["total_amt"]].sum()

# %%
male_electronics_earning
# Out:
#                            total_amt
# Gender prod_cat
# F      Bags              2079618.840
#        Books             6174590.825
#        Clothing          3026750.805
#        Electronics       5019354.210
#        Footwear          3203155.215
#        Home and kitchen  4133702.235
# M      Bags              2046722.990
#        Books             6645972.775
#        Clothing          3224079.495
#        Electronics       5711351.620
#        Footwear          3020200.365
#        Home and kitchen  4305169.505

# %%
#10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
only_positive=customer_final.loc[customer_final["total_amt"]>0,:]

# %%
only_positive
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 10        29258453508   270384 2014-02-20                 5              3
# 11        25455265351   267750 2014-02-20                12              6
# 12         1571002198   275023 2014-02-20                 6              5
# 14        36554696014   269345 2014-02-20                 3              5
# 15        56814940239   268799 2014-02-20                 7              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
only_unique= only_positive.groupby(['customer_Id','prod_cat','Qty'])['transaction_id'].count().reset_index()

# %%
only_unique
# Out:
#        customer_Id          prod_cat  Qty  transaction_id
# 0           266783             Books    2               1
# 1           266783          Clothing    1               1
# 2           266783          Clothing    3               1
# 3           266783          Footwear    4               1
# 4           266784             Books    3               1
# ...            ...               ...  ...             ...
# 19534       275264             Books    5               1
# 19535       275264  Home and kitchen    4               1
# 19536       275265              Bags    1               1
# 19537       275265             Books    3               1
# 19538       275265  Home and kitchen    3               1
#
# [19539 rows x 4 columns]

# %%
final=only_unique.groupby('customer_Id')['transaction_id'].count().reset_index()

# %%
final[final['transaction_id'] > 10]
# Out:
#    customer_Id  transaction_id
# 4       266794              11

# %%
# 11. finding all customers between 25 and 35

# %%
from datetime import datetime, date

# %%
now = pd.Timestamp('now')
age=(now - (customer_final['DOB'])).astype('<m8[Y]')
age
# Out:
# 0        40.0
# 1        48.0
# 2        29.0
# 3        40.0
# 4        29.0
#          ...
# 23048    49.0
# 23049    37.0
# 23050    45.0
# 23051    51.0
# 23052    39.0
# Name: DOB, Length: 23040, dtype: float64

# %%
customer_final['age']=age
customer_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
def func(agedef):
    if agedef>25 and agedef<35:
        return agedef

# %%
new1=customer_final['age'].apply(func)

# %%
new1
# Out:
# 0         NaN
# 1         NaN
# 2        29.0
# 3         NaN
# 4        29.0
#          ...
# 23048     NaN
# 23049     NaN
# 23050     NaN
# 23051     NaN
# 23052     NaN
# Name: age, Length: 23040, dtype: float64

# %%
customer_final['newage']=new1

# %%
customer_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
customer_final['newage'].dropna?
# Out:
# Object `dropna` not found.

# %%
customer_final['newage'].dropna
# Out:
# <bound method Series.dropna of 0         NaN
# 1         NaN
# 2        29.0
# 3         NaN
# 4        29.0
#          ...
# 23048     NaN
# 23049     NaN
# 23050     NaN
# 23051     NaN
# 23052     NaN
# Name: newage, Length: 23040, dtype: float64>

# %%
customer_final['newage'].dropna
# Out:
# <bound method Series.dropna of 0         NaN
# 1         NaN
# 2        29.0
# 3         NaN
# 4        29.0
#          ...
# 23048     NaN
# 23049     NaN
# 23050     NaN
# 23051     NaN
# 23052     NaN
# Name: newage, Length: 23040, dtype: float64>

# %%
customer_final.dropna?

# %%
customer_final.dropna(subset=['newage'])
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 2         51750724947   273420 2014-02-24                 6              5
# 4         51750724947   273420 2014-02-23                 6              5
# 23        91116291703   268509 2014-02-20                 1              2
# 28        88853694830   268444 2014-02-20                 4              4
# 29        99581788104   267466 2014-02-20                 3              2
# ...               ...      ...        ...               ...            ...
# 23033     32887353269   268885 2011-01-25                 3              1
# 23034     28972634039   275227 2011-01-25                 9              3
# 23035     42161597232   267094 2011-01-25                 3              1
# 23038     61812307223   274306 2011-01-25                 4              4
# 23044     14787475597   273982 2011-01-25                 4              3
#
# ...

# %%
books_electronics = customer_final.groupby(['newage','prod_cat'])['total_amt'].sum()

# %%
books_electronics
# Out:
# newage  prod_cat
# 28.0    Bags                 30325.620
#         Books                62305.425
#         Clothing             41271.750
#         Electronics          68515.525
#         Footwear             54034.500
#         Home and kitchen     55226.795
# 29.0    Bags                157179.620
#         Books               580495.175
#         Clothing            284344.125
#         Electronics         447193.500
#         Footwear            278686.525
#         Home and kitchen    349449.620
# 30.0    Bags                151696.610
#         Books               524715.880
#         Clothing            266763.575
#         Electronics         383764.290
#         Footwear            233855.570
#         Home and kitchen    375737.570
# 31.0    Bags                173383.340
#         Books               433831.840
#         Clothing            283917.595
#         Electronics         412332.960
#         Footwear            279674.395
# ...

# %%
books_electronics.loc[:,['Books','Electronics']]
# Out:
# newage  prod_cat
# 28.0    Books           62305.425
#         Electronics     68515.525
# 29.0    Books          580495.175
#         Electronics    447193.500
# 30.0    Books          524715.880
#         Electronics    383764.290
# 31.0    Books          433831.840
#         Electronics    412332.960
# 32.0    Books          577910.580
#         Electronics    547317.550
# 33.0    Books          519830.675
#         Electronics    489424.390
# 34.0    Books          543246.730
#         Electronics    583680.890
# Name: total_amt, dtype: float64
