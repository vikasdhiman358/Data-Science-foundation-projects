# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
# %matplotlib inline

# %%
sales_data = pd.read_csv('SalesData.csv')

# %%
sales_data
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %% [markdown]
# # Question 1:- Compare Sales by region for 2016 with 2015 using Bar chart

# %%
region_totalsales = sales_data.groupby('Region')[['Sales2015' , 'Sales2016']].sum()

# %%
region_totalsales
# Out:
#             Sales2015     Sales2016
# Region
# Central  7.891729e+06  9.787809e+06
# East     9.512916e+06  1.266723e+07
# West     5.349745e+06  7.209689e+06

# %%
region_totalsales.plot(kind='bar')
plt.show()

# %% [markdown]
# # 2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart.

# %%
region_sales2016 = sales_data.groupby('Region')[['Sales2016']].sum()

# %%
region_sales2016
# Out:
#             Sales2016
# Region
# Central  9.787809e+06
# East     1.266723e+07
# West     7.209689e+06

# %%
region_sales2016.plot(kind='pie', subplots=True, autopct = '%.1f%%')
plt.show()

# %% [markdown]
# # 3. Compare the total sales of 2015 and 2016 with respect to Region and Tiers

# %%
sales_tier = sales_data.groupby(['Region' , 'Tier'])[['Sales2015' , 'Sales2016']].sum()

# %%
sales_tier.plot(kind = 'bar')
plt.show()

# %% [markdown]
# # 4. In East region, which state registered a decline in 2016 as compared to 2015?

# %%
region_state = sales_data.groupby(['Region' , 'State'])[['Sales2015' , 'Sales2016']].sum()

# %%
region_state
# Out:
#                   Sales2015     Sales2016
# Region  State
# Central AL     5.091037e+05  5.958284e+05
#         AR     2.133175e+05  2.276081e+05
#         IL     6.217938e+05  7.843074e+05
#         IN     3.166781e+05  5.996723e+05
#         KY     5.312149e+05  6.332189e+05
#         LA     4.793662e+05  6.803033e+05
#         MI     5.686517e+05  7.072480e+05
#         MS     3.045782e+05  2.204109e+05
#         OH     9.276875e+05  1.221085e+06
#         OK     2.484607e+05  3.396445e+05
#         PA     3.002670e+05  2.877924e+05
#         TN     4.370386e+05  5.522301e+05
#         TX     1.712440e+06  2.013116e+06
#         WI     3.044250e+05  4.403802e+05
#         WV     4.167062e+05  4.849640e+05
# East    CT     1.972028e+05  3.235023e+05
#         DC     2.167240e+05  2.574217e+05
#         FL     1.660162e+06  2.508232e+06
#         GA     6.815465e+05  9.469198e+05
#         MA     4.192788e+05  6.870964e+05
#         MD     5.273091e+05  7.500088e+05
# ...

# %%
a=region_state.loc['East']

# %%
a
# Out:
#          Sales2015   Sales2016
# State
# CT      197202.790   323502.31
# DC      216723.950   257421.69
# FL     1660162.000  2508232.28
# GA      681546.460   946919.77
# MA      419278.750   687096.45
# MD      527309.060   750008.79
# ME       77425.640   183673.05
# NC     1292801.640  1610521.00
# NH      136419.380   144717.51
# NJ      520419.290   782289.19
# NY     1725415.065  1703135.80
# PA      785092.755   894319.49
# RI      156311.800   162454.65
# SC      247811.780   463414.12
# TN       49677.000    70109.41
# VA      819319.130  1179414.94

# %%
a.plot(kind='bar')
plt.show()

# %% [markdown]
# by looking at graph we can say that NY registered a small decline in sales

# %% [markdown]
# # 5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015?

# %%
tier_sales = sales_data.groupby(['Tier' , 'Division'])[['Units2015' , 'Units2016']].sum()

# %%
tier_sales
# Out:
#                     Units2015  Units2016
# Tier Division
# High BIG APPLE       180.8330   231.0000
#      CHARGERS        123.6666   164.4999
#      CONGRESSIONAL   164.5003   205.0000
#      DIAMONDBACK     153.3334   176.6667
#      EMPIRE          414.3332   449.3332
# ...                       ...        ...
# Out  SYNERGY           3.0000     0.0000
#      THE CAROLINAS     2.0000     0.0000
#      VICTORY           1.0000     0.0000
#      WOLVERINE         1.0000     0.0000
#      WRANGLER         13.0000     0.0000
#
# [96 rows x 2 columns]

# %%
b=tier_sales.loc['High']

# %%
b
# Out:
#                 Units2015  Units2016
# Division
# BIG APPLE        180.8330   231.0000
# CHARGERS         123.6666   164.4999
# CONGRESSIONAL    164.5003   205.0000
# DIAMONDBACK      153.3334   176.6667
# EMPIRE           414.3332   449.3332
# GRIDIRON         213.6673   246.1675
# GULF STREAM      185.0000   301.0009
# HAILSTORM        187.8338   247.0003
# KINETIC          214.3334   244.5001
# MINUTEMEN        215.0000   267.5000
# MUDDY WATERS     150.6666   211.5004
# NORDIC           210.1675   225.8334
# NORTHWEST        135.5008   163.6669
# ORION            175.8334   276.0000
# RACEWAY          178.3338   297.0000
# REVOLUTION       205.8335   226.8334
# RIPTIDE          147.5002   183.8336
# SOUTHERN STAR    230.0000   274.1665
# STAMPEDE         192.4999   246.8333
# SYNERGY          322.6666   428.3334
# THE CAROLINAS    258.8335   345.0000
# TORNADO VALLEY   128.3331   181.0004
# VICTORY          174.5005   221.1669
# WAVE RIDER       173.4996   223.3332
# ...

# %%
b.plot(kind='bar', figsize=(14,10))
plt.show()

# %% [markdown]
# by looking at graph we can say that there is no decline in number of unit sold

# %% [markdown]
# # 6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. The Quarters are based on months and defined as -
# • Jan - Mar : Q1
# • Apr - Jun : Q2
# • Jul - Sep : Q3
# • Oct - Dec : Q4

# %%
sales_data['Qtr'] = np.where((sales_data.Month == 'Jan') | (sales_data.Month == 'Feb') | (sales_data.Month == 'Mar') , 'Q1',
np.where((sales_data.Month == 'Apr') | (sales_data.Month == 'May') | (sales_data.Month == 'Jun') , 'Q2', 
np.where((sales_data.Month == 'Jul') | (sales_data.Month == 'Aug') | (sales_data.Month == 'Sep') , 'Q3','Q4' )))

# %%
sales_data
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %% [markdown]
# # 7. Compare Qtr wise sales in 2015 and 2016 in a bar plot

# %%
qtr_sales = sales_data.groupby('Qtr')[['Sales2015' , 'Sales2016']].sum()

# %%
qtr_sales
# Out:
#         Sales2015     Sales2016
# Qtr
# Q1   5.485800e+06  6.997953e+06
# Q2   5.390862e+06  7.237361e+06
# Q3   6.164094e+06  7.861546e+06
# Q4   5.713634e+06  7.567868e+06

# %%
qtr_sales.plot(kind='bar' , figsize=(12,8))
plt.show()

# %% [markdown]
# # 8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart.

# %%
qtr_tier_sales = sales_data.groupby(['Qtr' , 'Tier'])[['Sales2016']].sum()

# %%
qtr_tier_sales
# Out:
#              Sales2016
# Qtr Tier
# Q1  High  3.867719e+06
#     Low   9.488328e+05
#     Med   2.181402e+06
#     Out   0.000000e+00
# Q2  High  4.130953e+06
#     Low   8.905948e+05
#     Med   2.215814e+06
#     Out   0.000000e+00
# Q3  High  4.872559e+06
#     Low   7.951777e+05
#     Med   2.197058e+06
#     Out  -3.248530e+03
# Q4  High  4.740002e+06
#     Low   7.426594e+05
#     Med   2.085207e+06
#     Out   0.000000e+00

# %%
q1 = qtr_tier_sales.loc['Q1']

# %%
q1
# Out:
#         Sales2016
# Tier
# High  3867718.595
# Low    948832.770
# Med   2181401.879
# Out         0.000

# %%
q1.plot(kind='pie' , subplots=True , autopct = '%.1f%%')
plt.show()

# %%
q2 = qtr_tier_sales.loc['Q2']

# %%
q2
# Out:
#          Sales2016
# Tier
# High  4.130953e+06
# Low   8.905948e+05
# Med   2.215814e+06
# Out   0.000000e+00

# %%
q2.plot(kind='pie' , subplots=True , autopct = '%.1f%%')
plt.show()

# %%
q3 = qtr_tier_sales.loc['Q3']

# %%
q3
# Out:
#          Sales2016
# Tier
# High  4.872559e+06
# Low   7.951777e+05
# Med   2.197058e+06
# Out  -3.248530e+03

# %%
q3.plot(kind='pie' , subplots=True , autopct = '%.1f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-39c1ced03431> in <module>
# ----> 1 q3.plot(kind='pie' , subplots=True , autopct = '%.1f%%')
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ...

# %%
q4 = qtr_tier_sales.loc['Q4']

# %%
q4
# Out:
#          Sales2016
# Tier
# High  4.740002e+06
# Low   7.426594e+05
# Med   2.085207e+06
# Out   0.000000e+00

# %%
q4.plot(kind='pie' , subplots=True , autopct = '%.1f%%')
plt.show()
