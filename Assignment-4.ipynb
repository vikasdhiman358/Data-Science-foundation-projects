# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime,timedelta

# %%
customer_acquisition=pd.read_csv('C:\\Users\\TSL\Desktop\\AL\\assignments\\4th\\Customer Acqusition.csv')

# %%
customer_acquisition
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
customer_acquisition.dtypes
# Out:
# No            int64
# Customer     object
# Age           int64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# dtype: object

# %%
customer_acquisition.isnull().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
customer_acquisition.drop('No',axis=1,inplace=True)

# %%
customer_acquisition
# Out:
#    Customer  Age        City   Product     Limit Company        Segment
# 0        A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..      ...  ...         ...       ...       ...     ...            ...
# 95      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 7 columns]

# %%
spend_data=pd.read_csv('C:\\Users\\TSL\Desktop\\AL\\assignments\\4th\\spend.csv')

# %%
spend_data
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
spend_data.drop('Sl No:',axis=1,inplace=True)

# %%
spend_data
# Out:
#      Customer      Month        Type     Amount
# 0          A1  12-Jan-04   JEWELLERY  485470.80
# 1          A1   3-Jan-04       PETRO  410556.13
# 2          A1  15-Jan-04     CLOTHES   23740.46
# 3          A1  25-Jan-04        FOOD  484342.47
# 4          A1  17-Jan-05      CAMERA  369694.07
# ...       ...        ...         ...        ...
# 1495      A67   4-Feb-06  BUS TICKET  356872.73
# 1496      A68  25-Mar-06  BUS TICKET  204971.10
# 1497      A69  31-Mar-06  BUS TICKET   50449.44
# 1498      A70  23-Mar-06  BUS TICKET   80593.94
# 1499      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 4 columns]

# %%
spend_data.dtypes
# Out:
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
spend_data['Month']=pd.to_datetime(spend_data['Month'])

# %%
spend_data.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# dtype: object

# %%
spend_data.isnull().sum()
# Out:
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
repayment_data=pd.read_csv('C:\\Users\\TSL\Desktop\\AL\\assignments\\4th\\Repayment.csv')

# %%
repayment_data
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
repayment_data.drop('Unnamed: 4', axis=1, inplace=True)

# %%
repayment_data
# Out:
#       SL No: Customer      Month     Amount
# 0        NaN       A1  12-Jan-04  495414.75
# 1        2.0       A1   3-Jan-04  245899.02
# 2        3.0       A1  15-Jan-04  259490.06
# 3        4.0       A1  25-Jan-04  437555.12
# 4        5.0       A1  17-Jan-05  165972.88
# ...      ...      ...        ...        ...
# 1518     NaN      NaN        NaN        NaN
# 1519     NaN      NaN        NaN        NaN
# 1520     NaN      NaN        NaN        NaN
# 1521     NaN      NaN        NaN        NaN
# 1522     NaN      NaN        NaN        NaN
#
# [1523 rows x 4 columns]

# %%
repayment_data.dropna(axis=0,inplace=True)

# %%
repayment_data
# Out:
#       SL No: Customer      Month     Amount
# 1        2.0       A1   3-Jan-04  245899.02
# 2        3.0       A1  15-Jan-04  259490.06
# 3        4.0       A1  25-Jan-04  437555.12
# 4        5.0       A1  17-Jan-05  165972.88
# 5        6.0       A1  23-Feb-05  365366.62
# ...      ...      ...        ...        ...
# 1495  1496.0      A67   9-May-05   55638.77
# 1496  1497.0      A68  10-May-06  319836.49
# 1497  1498.0      A69  11-Jul-06  247628.45
# 1498  1499.0      A70  12-Aug-05  454016.51
# 1499  1500.0      A71  13-Sep-04   56286.33
#
# [1499 rows x 4 columns]

# %%
repayment_data.dtypes
# Out:
# SL No:      float64
# Customer     object
# Month        object
# Amount      float64
# dtype: object

# %%
repayment_data['Month']=pd.to_datetime(repayment_data['Month'])

# %%
repayment_data.dtypes
# Out:
# SL No:             float64
# Customer            object
# Month       datetime64[ns]
# Amount             float64
# dtype: object

# %%
repayment_data.isnull().sum()
# Out:
# SL No:      0
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %%
#a. In case age is less than 18, replace it with mean of age values.

# %%
customer_acquisition['Age'] = np.where(customer_acquisition['Age'] > 18, customer_acquisition.Age.mean(), customer_acquisition['Age'])

# %%
customer_acquisition
# Out:
#    Customer    Age        City   Product     Limit Company        Segment
# 0        A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2  46.49    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3  46.49      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4  46.49      BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5  46.49   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..      ...    ...         ...       ...       ...     ...            ...
# 95      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 7 columns]

# %%
#b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit. (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
Customer_Spend_limit=pd.merge(left=customer_acquisition,right=spend_data,on='Customer')

# %%
Customer_Spend_limit
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1495      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount
# ...

# %%
Customer_Spend_limit['Amount']=np.where(Customer_Spend_limit.Amount>Customer_Spend_limit.Limit,Customer_Spend_limit.Limit/2,Customer_Spend_limit.Amount)

# %%
Customer_Spend_limit
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1495      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount
# ...

# %%
#c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
Customer_Repayment_Replace=pd.merge(left=customer_acquisition,right=repayment_data,on='Customer')

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#       SL No:      Month     Amount
# ...

# %%
Customer_Repayment_Replace['Amount']=np.where(Customer_Repayment_Replace.Amount>Customer_Repayment_Replace.Limit,Customer_Repayment_Replace.Limit,Customer_Repayment_Replace.Amount)

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#       SL No:      Month     Amount
# ...

# %%
#From the above dataset create the following summaries:
#a. How many distinct customers exist?

# %%
Customer_Spend_limit['Customer'].nunique()
# Out:
# 100

# %%
Customer_Repayment_Replace['Customer'].nunique()
# Out:
# 100

# %%
Customer_Spend_limit['Product'].nunique()
# Out:
# 3

# %%
Customer_Repayment_Replace['Product'].nunique()
# Out:
# 3

# %%
#c. What is the average monthly spend by customers?

# %%
#d. What is the average monthly repayment by customers?

# %%
#e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month? (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment – Monthly spend. Interest is earned only on positive profits and not on negative amounts)¶

# %%
#f. What are the top 5 product types?

# %%
Customer_Spend_limit.groupby('Type').Amount.sum().reset_index().sort_values('Amount',ascending=False)
# Out:
#             Type       Amount
# 10         PETRO  28597384.98
# 4         CAMERA  27690738.44
# 7           FOOD  20519243.60
# 0     AIR TICKET  20155847.12
# 14  TRAIN TICKET  19995825.72
# 13      SHOPPING  17106660.97
# 3     BUS TICKET  16279935.35
# 9   MOVIE TICKET  13001899.29
# 6        CLOTHES  12302511.36
# 11        RENTAL  11850628.72
# 8      JEWELLERY  11507786.00
# 2           BIKE   7009789.53
# 5            CAR   5107867.45
# 1           AUTO   4806060.41
# 12       SANDALS   3848906.29

# %%
Customer_Repayment_Replace.groupby('City').Amount.sum().reset_index().sort_values('Amount',ascending=False)
# Out:
#          City       Amount
# 4      COCHIN  50702815.75
# 0   BANGALORE  49346348.29
# 2    CALCUTTA  40949671.32
# 1      BOMBAY  34494040.96
# 3     CHENNAI  20994469.37
# 7  TRIVANDRUM  17267188.25
# 6       PATNA  16633138.29
# 5       DELHI  14099273.11

# %%
#h. Which age group is spending more money?

# %%
Customer_Spend_limit['Age_Group']=np.where(((Customer_Spend_limit.Age.astype(int) >= 18) & (Customer_Spend_limit.Age.astype(int) < 25)), 'Youth',np.where(((Customer_Spend_limit.Age.astype(int) >= 25) & (Customer_Spend_limit.Age.astype(int) < 65)), 'Adult','Senior'))

# %%
Customer_Spend_limit
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1495      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount Age_Group
# ...

# %%
Customer_Spend_limit.groupby('Age_Group').Amount.sum()
# Out:
# Age_Group
# Adult     2.039085e+08
# Senior    1.587255e+07
# Name: Amount, dtype: float64

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#       SL No:      Month     Amount
# ...

# %%
Customer_Repayment_Replace.groupby('Customer').Amount.sum().reset_index().sort_values('Amount',ascending=False)
# Out:
#    Customer       Amount
# 58      A61  10539142.91
# 57      A60   9876290.74
# 5       A13   9572000.66
# 38      A43   8489871.46
# 40      A45   8448334.87
# ..      ...          ...
# 82      A83     10002.00
# 99      A99     10002.00
# 98      A98     10001.00
# 97      A97     10000.00
# 75      A77      3159.62
#
# [100 rows x 2 columns]

# %%
#3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
def func(x):
    x=x.year
    return x

# %%
Customer_Repayment_Replace['Year']=Customer_Repayment_Replace['Month'].apply(func)

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#       SL No:      Month     Amount  Year
# ...

# %%
City_Wise_Data=Customer_Spend_limit.groupby(['Product', 'City'])['Amount'].sum()

# %%
City_Wise_Data
# Out:
# Product   City
# Gold      BANGALORE     34212852.62
#           BOMBAY        23888016.12
#           CALCUTTA      28948029.55
#           CHENNAI        7504852.70
#           COCHIN        29925605.56
#           DELHI          7728443.59
#           PATNA          7601365.36
#           TRIVANDRUM     6391189.56
# Platimum  BANGALORE      2710848.54
#           BOMBAY         2581199.89
#           CALCUTTA      10061993.27
#           CHENNAI       13614532.10
#           COCHIN        13301418.07
#           DELHI           954459.47
#           PATNA          5252438.32
#           TRIVANDRUM     7910523.72
# Silver    BANGALORE      3537945.86
#           BOMBAY         2133911.37
#           CALCUTTA       2098109.48
#           CHENNAI        1009250.85
#           COCHIN         2736489.87
#           DELHI          2235383.48
#           PATNA          2406783.29
#           TRIVANDRUM     1035442.59
# Name: Amount, dtype: float64

# %%
City_Wise_Data.plot(kind='bar')
plt.show()

# %%
#4. Create graphs for
#a. Monthly comparison of total spends, city wise

# %%
def func(x):
    x=x.month
    return x

# %%
Customer_Spend_limit.head(5)
# Out:
#   Customer    Age       City Product     Limit Company        Segment  \
# 0       A1  46.49  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  46.49  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  46.49  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  46.49  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  46.49  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_Group
# 0 2004-01-12  JEWELLERY  485470.80     Adult
# 1 2004-01-03      PETRO  410556.13     Adult
# 2 2004-01-15    CLOTHES   23740.46     Adult
# 3 2004-01-25       FOOD  484342.47     Adult
# 4 2005-01-17     CAMERA  369694.07     Adult

# %%
Customer_Spend_limit['Month_number']=Customer_Spend_limit['Month'].apply(lambda x:x.month)

# %%
Customer_Spend_limit
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1495      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
pd.pivot_table(data = Customer_Spend_limit, index = 'City', columns='Month_number', values='Amount', aggfunc='sum').plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='City'>

# %%
comparison.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='Month_number,City'>

# %%
#b. Comparison of yearly spend on air tickets

# %%
#c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
pd.pivot_table(data = Customer_Spend_limit, index = 'Product', columns='Month_number', 
               values='Amount', aggfunc='sum').plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Product'>

# %%
#5. Write user defined PYTHON function to perform the following analysis: 
#You need to find top 10 customers for each city in terms of their repayment amount by different products 
#and by different time periods i.e. year or month. 
#The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly)
#and the function should automatically take these inputs while identifying the top 10 customers.

# %%
Customer_Repayment_Replace['yearly']=Customer_Repayment_Replace.Month.apply(lambda x:x.year)

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#       SL No:      Month     Amount  Year  yearly
# ...

# %%
Customer_Repayment_Replace['monthly']=Customer_Repayment_Replace.Month.apply(lambda x:x.month)

# %%
Customer_Repayment_Replace
# Out:
#      Customer    Age        City   Product     Limit Company        Segment  \
# 0          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  46.49   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...    ...         ...       ...       ...     ...            ...
# 1494      A96  46.49     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1495      A97  46.49  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1496      A98  46.49    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1497      A99  46.49    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1498     A100  46.49      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
def func(user_product, user_time):
    top10=Customer_Repayment_Transaction.loc[(Customer_Repayment_Transaction.Product == product_category)]
    top10.groupby(['Customer','City','Product',time_period]).Amount.sum()
    return top10
